# %% [markdown]
# # Pemanggilan Data

# %%
import pandas as pd

data_febi = pd.read_csv('R02_rice_field.csv')
data_febi
# Out:
#      Production (X)  Harvest Area (Y)
# 0        1329536.00         323589.00
# 1        1299699.00         329041.00
# 2        1382905.00         339253.00
# 3        1419128.00         348223.00
# 4        1368074.00         337561.00
# ..              ...               ...
# 219      3831923.00         390799.00
# 220      4090654.00         396559.00
# 221      2488641.91         511940.93
# 222      2164089.33         464103.42
# 223      2604913.29         545149.05
#
# [224 rows x 2 columns]

# %% [markdown]
# # Preprocessing Data

# %%
from sklearn.model_selection import train_test_split

X = data_febi['Production (X)'].values.reshape(-1,1)
Y = data_febi['Harvest Area (Y)'].values

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=.2)

# %% [markdown]
# # Modelling

# %%
from sklearn.linear_model import LinearRegression

febi = LinearRegression()
febi.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Analisis Akurasi Model

# %%
print("Akurasi model: ", febi.score(x_train, y_train))
# Out:
# Akurasi model:  0.7929011274384432

# %% [markdown]
# # Pengujian model

# %%
prediksi = febi.predict(x_test)
prediksi
# Out:
# array([652633.6620311 , 490540.39077752, 783724.21694174, 176425.99291759,
#        126853.3918715 , 148640.63363322, 122929.85143361, 618742.37219591,
#        627810.1530019 , 135354.62962491, 392470.54879075, 679947.7065754 ,
#        352207.85316339, 123449.00068488, 480049.74662268, 152646.54659643,
#        173679.42594443, 130547.338198  , 348615.71781614, 188637.50424949,
#        389381.90700069, 391386.26256129, 415292.67530223, 169283.69459325,
#        454811.29349541, 728184.27811113, 442203.26043825, 162783.39864768,
#        422152.53455228, 344507.84697039, 176879.81917008, 392261.03670964,
#        386409.03899835, 417564.25495293, 648646.98640423, 637200.94617334,
#        671491.14841005, 418584.00866324, 142271.67622932, 420219.70690584,
#        346978.97026429, 447825.45942284, 567364.86829228, 484009.48997869,
#        394646.11664468])

# %% [markdown]
# # Visualisasi Data

# %%
import matplotlib.pyplot as plt

plt.scatter(x_test, y_test, c='green')
plt.plot(x_test, prediksi, c='red')
plt.xlabel("Production")
plt.ylabel("Harvest Area")
plt.show()
